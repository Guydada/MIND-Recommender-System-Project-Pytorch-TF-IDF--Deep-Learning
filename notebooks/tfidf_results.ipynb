# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ti = pd.read_csv('../results/tfidf_scores_MindTF_IDF_train_size_49108.pkl -final.csv')
fg_tc = pd.read_csv("../results/tfidf_scores_MindTF_IDF_train_cols_['title', 'category']_size_49108.csv")

# %%
df_ti
# Out:
#        behave_index user_id  nDCG - baseline  nDCG - tfidf  nDCG%5 - baseline  \
# 0                 0    U100         0.198893      0.198893           0.018735
# 1                 1   U1000         0.255655      0.255655           0.003005
# 2                 2  U10001         0.284398      0.284398           0.014209
# 3                 3  U10003         0.269297      0.269297           0.011174
# 4                 4  U10008         0.219610      0.219610           0.027443
# ...             ...     ...              ...           ...                ...
# 49103         49103   U9993         0.280792      0.280792           0.030485
# 49104         49104   U9995         0.351019      0.410018           0.000000
# 49105         49105   U9996         0.411939      0.411939           0.071934
# 49106         49106   U9997         0.337487      0.337487           0.000000
# 49107         49107   U9999         0.401514      0.401514           0.063942
#
# ...

# %%
# set figure size
plt.rcParams['figure.figsize'] = (15, 10)
sns.boxplot(data=df_ti.drop(['behave_index'], axis=1))
# add labels
plt.xlabel('Score Metric')
plt.ylabel('nDCG Score')
plt.title('nDCG Score')
# add labels of mean and std on the boxplot on each box
plt.text(0.5, 0.9, 'Mean: ' + str(df_ti.drop(['behave_index'], axis=1).mean().round(2)),
         horizontalalignment='center',
         verticalalignment='center',
         transform=plt.gca().transAxes)
plt.show()

# %%
# set figure size
plt.rcParams['figure.figsize'] = (15, 10)
sns.boxplot(data=fg_tc.drop(['behave_index'], axis=1))
# add labels
plt.xlabel('Score Metric')
plt.ylabel('nDCG Score')
plt.title('nDCG Score')
# add labels of mean and std on the boxplot on each box
plt.text(0.5, 0.9, 'Mean: ' + str(df_ti.drop(['behave_index'], axis=1).mean().round(2)),
         horizontalalignment='center',
         verticalalignment='center',
         transform=plt.gca().transAxes)
plt.show()
