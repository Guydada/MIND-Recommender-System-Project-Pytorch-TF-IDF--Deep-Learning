# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns

# %%
df = pd.read_csv('../results/loss_df_MindTensor_train_size_463060.pt_2021-12-31_18.csv')

# %%
df['running_loss'][700000:].plot()
# Out:
# <AxesSubplot:>

# %%
df2 = pd.read_csv('../results/test_metrics_2021-12-31_18.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41532 entries, 0 to 41531
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  41532 non-null  int64
#  1   batch_num   41532 non-null  float64
#  2   f1          41532 non-null  float64
#  3   accuracy    41532 non-null  float64
#  4   recall      41532 non-null  float64
#  5   precision   41532 non-null  float64
#  6   loss        41532 non-null  float64
# dtypes: float64(6), int64(1)
# memory usage: 2.2 MB

# %%
df2.drop(['Unnamed: 0', 'batch_num'], axis=1).plot()
# Out:
# <AxesSubplot:>
