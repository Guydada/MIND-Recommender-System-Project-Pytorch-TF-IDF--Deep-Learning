# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
loss = pd.read_csv('../results/loss_df_MindTensorDot_train_cols_title_size_456779_2022-01-08_13_39.csv')
test = pd.read_csv('../results/test_df_MindTensorDot_test_cols_title_size_2658091_2022-01-08_13_39.csv')

# %%
loss
# Out:
#        Unnamed: 0      loss  epoch  batch  running_loss       acc
# 0               0  0.694613      0      0      0.694613  0.484375
# 1               0  0.691161      0      1      0.691161  0.578125
# 2               0  0.697968      0      2      0.697968  0.390625
# 3               0  0.694634      0      3      0.694634  0.453125
# 4               0  0.691671      0      4      0.691671  0.609375
# ...           ...       ...    ...    ...           ...       ...
# 71365           0  0.714616      9   7132      0.714616  0.453125
# 71366           0  0.654221      9   7133      0.654221  0.625000
# 71367           0  0.668650      9   7134      0.668650  0.593750
# 71368           0  0.674921      9   7135      0.674921  0.578125
# 71369           0  0.712733      9   7136      0.712733  0.468750
#
# [71370 rows x 6 columns]

# %%
# set default figure size
plt.rcParams['figure.figsize'] = [15, 10]
loss[['loss']].loc[70000:].plot()
plt.title('Loss - MindTensorDot, train')
# Out:
# Text(0.5, 1.0, 'Loss - MindTensorDot, train')

# %%
loss.plot(y='acc', label='train')
plt.title('Accuracy - MindTensorDot, test')
# Out:
# Text(0.5, 1.0, 'Accuracy - MindTensorDot, test')

# %%
test.plot(y='accuracy', label='train')
plt.title('Accuracy - MindTensorDot, test')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\ve_mind\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'accuracy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9844/1967047938.py in <module>
# ...

# %%
test.drop(columns=['Unnamed: 0', 'batch_num']).plot()
plt.title('Model Metrics - MindTensorDot, test')
# Out:
# Text(0.5, 1.0, 'Model Metrics - MindTensorDot, test')
