# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
loss = pd.read_csv('../results/loss_df_MindTensorDot_train_cols_title_size_29238_2022-01-08_11_56.csv')
test = pd.read_csv('../results/MindTensorDot_test_cols_title_size_366145_2022-01-08_11_56.csv')

# %%
loss.plot(x='epoch', y='loss', label='train')
# Out:
# <AxesSubplot:xlabel='epoch'>

# %%
test
# Out:
#     Unnamed: 0  batch_num        f1  accuracy  recall  precision      loss
# 0            0        0.0  0.060606  0.031250     1.0   0.031250  0.722713
# 1            1        1.0  0.089552  0.046875     1.0   0.046875  0.720620
# 2            2        2.0  0.108374  0.057292     1.0   0.057292  0.719772
# 3            3        3.0  0.103704  0.054688     1.0   0.054688  0.721871
# 4            4        4.0  0.106509  0.056250     1.0   0.056250  0.720800
# ..         ...        ...       ...       ...     ...        ...       ...
# 95          95       95.0  0.081798  0.042643     1.0   0.042643  0.721563
# 96          96       96.0  0.081879  0.042687     1.0   0.042687  0.721747
# 97          97       97.0  0.081664  0.042570     1.0   0.042570  0.722926
# 98          98       98.0  0.080872  0.042140     1.0   0.042140  0.724528
# 99          99       99.0  0.081822  0.042656     1.0   0.042656  0.718695
#
# [100 rows x 7 columns]

# %%
test.drop(columns=['Unnamed: 0', 'batch_num']).plot()
# Out:
# <AxesSubplot:>
